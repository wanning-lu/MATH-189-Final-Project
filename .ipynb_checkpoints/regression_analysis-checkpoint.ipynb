# %%
# %%capture
# %run data_merging.ipynb

# %%
# before dropping columns
merged_years['2018']
# Out:
#             City status  Household Income    All  African American  \
# 0        Alameda    Adm            131116  260.0              14.0
# 1        Alameda    App            131116  374.0              26.0
# 2       Alhambra    Adm             72406  291.0               0.0
# 3       Alhambra    App             72406  474.0               5.0
# 4        Anaheim    Adm             85133  478.0               6.0
# ..           ...    ...               ...    ...               ...
# 273     Whittier    App             91457  486.0               6.0
# 274  Yorba Linda    Adm            151534   92.0               0.0
# 275  Yorba Linda    App            151534  140.0               0.0
# 276    Yuba City    Adm             59588   56.0               0.0
# 277    Yuba City    App             59588   87.0               0.0
#
#      American Indian  Hispanic/ Latinx  Pacific Islander  Asian  White  \
# 0                0.0              21.0               0.0  150.0   49.0
# ...

# %%
for year in years:
    print(year)
    merged_years[year] = merged_years[year].drop(['American Indian', 'Pacific Islander', 'Domestic Unknown', 'Int\'l', 'Other', 'Unknown'], axis=1)
# Out:
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023

# %%
# after dropping columns
merged_years['2018']
# Out:
#             City status  Household Income    All  African American  \
# 0        Alameda    Adm            131116  260.0              14.0
# 1        Alameda    App            131116  374.0              26.0
# 2       Alhambra    Adm             72406  291.0               0.0
# 3       Alhambra    App             72406  474.0               5.0
# 4        Anaheim    Adm             85133  478.0               6.0
# ..           ...    ...               ...    ...               ...
# 273     Whittier    App             91457  486.0               6.0
# 274  Yorba Linda    Adm            151534   92.0               0.0
# 275  Yorba Linda    App            151534  140.0               0.0
# 276    Yuba City    Adm             59588   56.0               0.0
# 277    Yuba City    App             59588   87.0               0.0
#
#      Hispanic/ Latinx  Asian  White  Female   Male  Measure Values
# 0                21.0  150.0   49.0   136.0  108.0        4.006577
# ...

# %% [markdown]
# Explanation for dropping the columns: As seen in the summary data, there's not much information on those particular groups in general, or they're too nondescriptive to be applied (for example, what is "Domestic Unknown"?).

# %%
(merged_years['2018']['African American'] == 0).sum()
# Out:
# 80
