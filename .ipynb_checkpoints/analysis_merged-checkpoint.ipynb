# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading data

# %%
# UC admissions data by ethnicity
years = ['2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

ethnicity = {}
gender = {}
gpa = {}
for year in years:
    ethnicity[f'{year}'] = pd.read_csv(f'ethnicity/{year}_ethn.csv', encoding='utf-16be', delimiter='\t', on_bad_lines='skip')
    gender[f'{year}'] = pd.read_csv(f'gender/{year}_gender.csv', encoding='utf-16le', delimiter='\t', on_bad_lines='skip')
    gpa[f'{year}'] = pd.read_csv(f'GPA/{year}_gpa.csv', index_col=0)

# specifically for 2017 ethnicity data, it uses utf-8 for some reason
ethnicity['2017'] = pd.read_csv(f'ethnicity/2017_ethn.csv', encoding='utf-8')

# median income by household at city level from census
census = pd.read_csv('https://raw.githubusercontent.com/wanning-lu/MATH-189-Final-Project/master/Census/ACSST1Y2022.S1903-2024-05-27T042652.csv', index_col = 0)

# %% [markdown]
# ### Filtering income data to contain only Californian cities

# %%
# using regex
pattern = r'California'  # this pattern matches any column name containing 'Measure'
# use filter to select columns that match the regex pattern
matching_columns = census.filter(regex=pattern).columns
# drop columns that do not match the pattern
census_filtered = census[matching_columns]

# repeat this so we narrow the data down to median income of californian cities
estimates = r'Estimate'
matching_columns2 = census_filtered.filter(regex=estimates).columns
census_income = census_filtered[matching_columns2]

Inc = r'Median income'
matching_columns3 = census_income.filter(regex=Inc).columns
california_income = census_filtered[matching_columns3]

# clean up column names
column_mapping = {col: col.split(',')[0] for col in california_income.columns}

# rename columns
california_income = california_income.rename(columns=column_mapping)

# clean up column names some more
def remove_last_word(s):
    return ' '.join(s.split()[:-1])

column_mapping = {col: remove_last_word(col) for col in california_income.columns}

california_income = california_income.rename(columns=column_mapping)

# lets get the cities as rows so we can merge it a bit easier
california_income = california_income.T

# lets bring the cities into a col so easier to merge
california_income = california_income.reset_index(drop=False)

# rename column
california_income = california_income.rename(columns={'index': 'City', '\xa0\xa0\xa0\xa0Households': 'Household Income'})

# lets keep only city and income data
california_income = california_income[['City', 'Household Income']]
# lets make income into ints
california_income['Household Income'] = california_income['Household Income'].str.replace(',', '').astype(int)
california_income.head()
# Out:
# Label (Grouping)                       City  Household Income
# 0                 California!!Median income             91551
# 1                                   Alameda            131116
# 2                                  Alhambra             72406
# 3                                   Anaheim             85133
# 4                                   Antioch            100178

# %% [markdown]
# ### NaN values in our UC data

# %%
#lets see how many Na values we have in our data

nan_df_ethn = ethnicity['2016'].isna()
nan_df_gender = gender['2016'].isna()
nan_df_gpa = gpa['2016'].isna()

# Create a figure with subplots 
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
fig2, ax2 = plt.subplots(1, 1, figsize=(15, 6))

# Set up the matplotlib figure
plt.figure(figsize=(10, 6))

# Create a heatmap
sns.heatmap(nan_df_ethn, cmap='viridis', cbar=False, ax=ax[0])
sns.heatmap(nan_df_gender, cmap='viridis', cbar=False, ax=ax[1])
sns.heatmap(nan_df_gpa, cmap='viridis', cbar=False, ax=ax2)

# Add labels and title
ax[0].set_xlabel('Ethnicity')
ax[0].set_ylabel('Schools')
ax[0].set_title('Heatmap of NaN Values in Ethnicity')

ax[1].set_xlabel('Gender')
ax[1].set_ylabel('Schools')
ax[1].set_title('Heatmap of NaN Values in Gender')

ax2.set_xlabel('GPA')
ax2.set_ylabel('Schools')
ax2.set_title('Heatmap of NaN Values in GPA')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 15
#      12 plt.figure(figsize=(10, 6))
#      14 # Create a heatmap
# ---> 15 sns.heatmap(nan_df_ethn, cmap='viridis', cbar=False, ax=ax[0])
#      16 sns.heatmap(nan_df_gender, cmap='viridis', cbar=False, ax=ax[1])
#      17 sns.heatmap(nan_df_gpa, cmap='viridis', cbar=False, ax=ax2)
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:202, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     200         vmin = np.nanpercentile(calc_data, 2)
#     201     else:
# --> 202         vmin = np.nanmin(calc_data)
#     203 if vmax is None:
#     204     if robust:
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:343, in nanmin(a, axis, out, keepdims, initial, where)
#     338     kwargs['where'] = where
#     340 if type(a) is np.ndarray and a.dtype != np.object_:
#     341     # Fast, but not safe for subclasses of ndarray, or object arrays,
#     342     # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 343     res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     344     if np.isnan(res).any():
#     345         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     346                       stacklevel=2)
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %% [markdown]
# The documentation say for any category with < 5 students, it is entered as null. We will have decide how we will deal with this.

# %% [markdown]
# ### Merge DataFrames across the categories

# %%
merged_years = {}
for year in years:
    print(ethnicity[f'{year}'].head())
    merged_years[f'{year}'] = pd.merge(ethnicity[f'{year}'][['Calculation1', 'School', 'City', 'County/State/ Territory', 'Count',
       'All', 'African American', 'American Indian', 'Hispanic/ Latinx',
       'Pacific Islander', 'Asian', 'White', 'Domestic Unknown', 'Int\'l']], california_income[['City', 'Household Income']], on='City', how='inner')
    merged_years[f'{year}'] = pd.merge(merged_years[f'{year}'], gender[f'{year}'], on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')
    merged_years[f'{year}'] = pd.merge(merged_years[f'{year}'], gpa[f'{year}'], on=['City','School'], how='inner')
    merged_years[f'{year}'] = merged_years[f'{year}'].set_index('Count')
    
    
# merged_df_16 = pd.merge(ethn_16, california_income, on='City', how='inner')
# merged_df_16 = pd.merge(merged_df_16, gen_16, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')
# merged_df_16 = pd.merge(merged_df_16, gpa_16, on=['City','School'], how='inner')
# merged_df_16 = merged_df_16.set_index('Count')
# merged_years['2016'].head()
# Out:
#                   Calculation1                  School      City  \
# 0  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL   Fontana
# 1  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL   Fontana
# 2  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL   Fontana
# 3            ABLE CHARTER54651            ABLE CHARTER  Stockton
# 4            ABLE CHARTER54651            ABLE CHARTER  Stockton
#
#   County/State/ Territory Count    All  African American  American Indian  \
# 0          San Bernardino   App  101.0               NaN              NaN
# 1          San Bernardino   Adm   76.0               NaN              NaN
# 2          San Bernardino   Enr   41.0               NaN              NaN
# 3             San Joaquin   App    6.0               NaN              NaN
# 4             San Joaquin   Adm    NaN               NaN              NaN
#
#    Hispanic/ Latinx  Pacific Islander  Asian  White  Domestic Unknown  Int'l
# 0              52.0               NaN    NaN    NaN              40.0    NaN
# 1              32.0               NaN    NaN    NaN              36.0    NaN
# 2              21.0               NaN    NaN    NaN              14.0    NaN
# 3               NaN               NaN    NaN    NaN               NaN    NaN
# 4               NaN               NaN    NaN    NaN               NaN    NaN
# Empty DataFrame
# Columns: [믯䎿污畣慬楴湯ⰱ捓潨汯䌬瑩ⱹ潃湵祴匯慴整 敔牲瑩牯ⱹ潃湵ⱴ汁ⱬ晁楲慣⁮流牥捩湡䄬敭楲慣⁮湉楤湡䠬獩慰楮⽣䰠瑡湩ⱸ慐楣楦⁣獉慬摮牥䄬楳湡圬楨整䐬浯獥楴⁣湕湫睯Ɱ湉❴൬㈊匱⁔䕃呎剕⁙䕌剁䥎䝎䤠华㕔㠴㘸㈬匱⁔䕃呎剕⁙䕌剁䥎䝎䤠华ⱔ敂畡潭瑮刬癩牥楳敤䄬灰ⰬⰬⰬⰬബ㈊匱⁔䕃呎剕⁙䕌剁䥎䝎䤠华㕔㠴㘸㈬匱⁔䕃呎剕⁙䕌剁�
䌠慬慲䄬浤ㄬ㈴Ⱜㄬⰱ㤬ⰷㄲⰬസ䄊剄䅉⁎⁃䥗䍌塏䠠䝉⁈䍓佈䱏㌵㜲ⰶ䑁䥒乁䌠圠䱉佃⁘䥈䡇匠䡃住ⱌ慓瑮⁡汃牡ⱡ慓瑮⁡汃牡ⱡ湅Ⱳ〷Ⱜ㌬Ⱜ㤴ㄬⰱ㔬਍䑁䱕⁔䥈䡇匠䡃住⁌‭䅐䍃㕄㠴㌴䄬啄呌䠠䝉⁈䍓佈䱏ⴠ倠䍁䑃倬獡摡湥ⱡ潌⁳湁敧敬ⱳ灁ⱰⰬⰬⰬⰬ਍䑁䱕⁔䥈䡇匠䡃住⁌‭䅐䍃㕄㠴㌴䄬啄呌䠠䝉⁈䍓佈䱏ⴠ倠䍁䑃倬獡摡湥ⱡ潌⁳湁敧敬ⱳ摁ⱭⰬⰬⰬⰬ਍䑁䱕⁔䥈䡇匠䡃住⁌‭䅐䍃㕄㠴㌴䄬啄呌䠠䝉⁈䍓佈䱏ⴠ倠䍁䑃倬獡摡湥ⱡ潌⁳湁敧敬ⱳ湅ⱲⰬⰬⰬⰬ਍䑁䅖䍎䑅䰠乒⁇䍁䵄⁙䅅䱒⁙佃䝌ㄵ〰ⰵ䑁䅖䍎䑅䰠乒⁇䍁䵄⁙䅅䱒⁙佃䝌匬湡慴䄠慮伬慲杮ⱥ灁ⱰㄱⰬㄬ ...
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 4
#       2 for year in years:
#       3     print(ethnicity[f'{year}'].head())
# ----> 4     merged_years[f'{year}'] = pd.merge(ethnicity[f'{year}'][['Calculation1', 'School', 'City', 'County/State/ Territory', 'Count',
#       5        'All', 'African American', 'American Indian', 'Hispanic/ Latinx',
#       6        'Pacific Islander', 'Asian', 'White', 'Domestic Unknown', 'Int\'l']], california_income[['City', 'Household Income']], on='City', how='inner')
#       7     merged_years[f'{year}'] = pd.merge(merged_years[f'{year}'], gender[f'{year}'], on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')
#       8     merged_years[f'{year}'] = pd.merge(merged_years[f'{year}'], gpa[f'{year}'], on=['City','School'], how='inner')
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Calculation1', 'School', 'City', 'County/State/ Territory', 'Count',\n       'All', 'African American', 'American Indian', 'Hispanic/ Latinx',\n       'Pacific Islander', 'Asian', 'White', 'Domestic Unknown', 'Int'l'],\n      dtype='object')] are in the [columns]"

# %%
ethnicity['2016'].columns
# Out:
# Index(['Calculation1', 'School', 'City', 'County/State/ Territory', 'Count',
#        'All', 'African American', 'American Indian', 'Hispanic/ Latinx',
#        'Pacific Islander', 'Asian', 'White', 'Domestic Unknown', 'Int'l'],
#       dtype='object')

# %%
merged_df_17 = pd.merge(ethnicity['2017'], california_income, on='City', how='inner')

merged_df_17 = pd.merge(merged_df_17, gen_17, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')

merged_df_17 = pd.merge(merged_df_17, gpa_17, on=['City','School'], how='inner')

merged_df_17.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/dh/twtyblw54yb66b4yl8q2hy6w0000gn/T/ipykernel_12628/203880161.py in ?()
# ----> 1 merged_df_17 = pd.merge(ethnicity['2017'], california_income, on='City', how='inner')
#       2
#       3 # merged_df_17 = pd.merge(merged_df_17, gen_17, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')
#       4
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1283                     if lk is not None:
#    1284                         # Then we're either Hashable or a wrong-length arraylike,
#    1285                         #  the latter of which will raise
#    1286                         lk = cast(Hashable, lk)
# -> 1287                         left_keys.append(left._get_label_or_level_values(lk))
#    1288                         join_names.append(lk)
#    1289                     else:
#    1290                         # work-around for merge_asof(left_index=True)
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'City'

# %%
merged_df_18 = pd.merge(ethn_18, california_income, on='City', how='inner')

merged_df_18 = pd.merge(merged_df_18, gen_18, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')

merged_df_18 = pd.merge(merged_df_18, gpa_18, on=['City','School'], how='inner')

merged_df_18.head()
# Out:
#                   Calculation1                  School     City  \
# 0  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 1  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 2  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 3  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 4  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
#
#   County/State/ Territory Count   All  African American  American Indian  \
# 0          San Bernardino   App  75.0               NaN              NaN
# 1          San Bernardino   App  75.0               NaN              NaN
# 2          San Bernardino   App  75.0               NaN              NaN
# 3          San Bernardino   Adm  56.0               NaN              NaN
# 4          San Bernardino   Adm  56.0               NaN              NaN
#
#    Hispanic/ Latinx  Pacific Islander  ...  Domestic Unknown  Int'l  \
# 0              53.0               NaN  ...              17.0    NaN
# 1              53.0               NaN  ...              17.0    NaN
# 2              53.0               NaN  ...              17.0    NaN
# 3              37.0               NaN  ...              14.0    NaN
# 4              37.0               NaN  ...              14.0    NaN
#
#    Household Income  Female  Male  Other  Unknown  County/State/Country  \
# 0             93581    37.0  26.0    NaN      NaN        San Bernardino
# 1             93581    37.0  26.0    NaN      NaN        San Bernardino
# 2             93581    37.0  26.0    NaN      NaN        San Bernardino
# 3             93581    25.0  20.0    NaN      NaN        San Bernardino
# 4             93581    25.0  20.0    NaN      NaN        San Bernardino
#
#    Measure Names Measure Values
# 0       Enrl GPA       3.891364
# 1        Adm GPA       3.659821
# 2        App GPA       3.569333
# 3       Enrl GPA       3.891364
# 4        Adm GPA       3.659821
#
# [5 rows x 22 columns]

# %%
merged_df_19 = pd.merge(ethn_19, california_income, on='City', how='inner')

merged_df_19 = pd.merge(merged_df_19, gen_19, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')

merged_df_19 = pd.merge(merged_df_19, gpa_19, on=['City','School'], how='inner')

merged_df_19.head()
# Out:
#                   Calculation1                  School     City  \
# 0  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 1  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 2  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 3  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 4  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
#
#   County/State/ Territory Count   All  African American  American Indian  \
# 0          San Bernardino   App  59.0               NaN              NaN
# 1          San Bernardino   App  59.0               NaN              NaN
# 2          San Bernardino   App  59.0               NaN              NaN
# 3          San Bernardino   Adm  50.0               NaN              NaN
# 4          San Bernardino   Adm  50.0               NaN              NaN
#
#    Hispanic/ Latinx  Pacific Islander  ...  Domestic Unknown  Int'l  \
# 0              34.0               NaN  ...              18.0    NaN
# 1              34.0               NaN  ...              18.0    NaN
# 2              34.0               NaN  ...              18.0    NaN
# 3              29.0               NaN  ...              16.0    NaN
# 4              29.0               NaN  ...              16.0    NaN
#
#    Household Income  Female  Male  Other  Unknown  County/State/Country  \
# 0             93581    21.0  20.0    NaN     18.0        San Bernardino
# 1             93581    21.0  20.0    NaN     18.0        San Bernardino
# 2             93581    21.0  20.0    NaN     18.0        San Bernardino
# 3             93581    16.0  18.0    NaN     16.0        San Bernardino
# 4             93581    16.0  18.0    NaN     16.0        San Bernardino
#
#    Measure Names Measure Values
# 0       Enrl GPA       3.921905
# 1        Adm GPA       3.732200
# 2        App GPA       3.670000
# 3       Enrl GPA       3.921905
# 4        Adm GPA       3.732200
#
# [5 rows x 22 columns]

# %%
merged_df_20 = pd.merge(ethn_20, california_income, on='City', how='inner')

merged_df_20 = pd.merge(merged_df_20, gen_20, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')

merged_df_20 = pd.merge(merged_df_20, gpa_20, on=['City','School'], how='inner')

merged_df_20.head()
# Out:
#                   Calculation1                  School     City  \
# 0  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 1  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 2  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 3  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 4  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
#
#   County/State/ Territory Count   All  African American  American Indian  \
# 0          San Bernardino   App  72.0               NaN              NaN
# 1          San Bernardino   App  72.0               NaN              NaN
# 2          San Bernardino   App  72.0               NaN              NaN
# 3          San Bernardino   Adm  61.0               NaN              NaN
# 4          San Bernardino   Adm  61.0               NaN              NaN
#
#    Hispanic/ Latinx  Pacific Islander  ...  Domestic Unknown  Int'l  \
# 0              65.0               NaN  ...               NaN    NaN
# 1              65.0               NaN  ...               NaN    NaN
# 2              65.0               NaN  ...               NaN    NaN
# 3              54.0               NaN  ...               NaN    NaN
# 4              54.0               NaN  ...               NaN    NaN
#
#    Household Income  Female  Male  Other  Unknown  County/State/Country  \
# 0             93581    45.0  26.0    NaN      NaN        San Bernardino
# 1             93581    45.0  26.0    NaN      NaN        San Bernardino
# 2             93581    45.0  26.0    NaN      NaN        San Bernardino
# 3             93581    38.0  23.0    NaN      NaN        San Bernardino
# 4             93581    38.0  23.0    NaN      NaN        San Bernardino
#
#    Measure Names Measure Values
# 0       Enrl GPA       3.815313
# 1        Adm GPA       3.731967
# 2        App GPA       3.630417
# 3       Enrl GPA       3.815313
# 4        Adm GPA       3.731967
#
# [5 rows x 22 columns]

# %%
merged_df_21 = pd.merge(ethn_21, california_income, on='City', how='inner')

merged_df_21 = pd.merge(merged_df_21, gen_21, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')

merged_df_21 = pd.merge(merged_df_21, gpa_21, on=['City','School'], how='inner')

merged_df_21.head()
# Out:
#                   Calculation1                  School     City  \
# 0  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 1  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 2  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 3  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 4  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
#
#   County/State/ Territory Count   All  African American  American Indian  \
# 0          San Bernardino   App  84.0               NaN              NaN
# 1          San Bernardino   App  84.0               NaN              NaN
# 2          San Bernardino   App  84.0               NaN              NaN
# 3          San Bernardino   Adm  61.0               NaN              NaN
# 4          San Bernardino   Adm  61.0               NaN              NaN
#
#    Hispanic/ Latinx  Pacific Islander  ...  Domestic Unknown  Int'l  \
# 0              74.0               NaN  ...               NaN    NaN
# 1              74.0               NaN  ...               NaN    NaN
# 2              74.0               NaN  ...               NaN    NaN
# 3              57.0               NaN  ...               NaN    NaN
# 4              57.0               NaN  ...               NaN    NaN
#
#    Household Income  Female  Male  Other  Unknown  County/State/Country  \
# 0             93581    58.0  26.0    NaN      NaN        San Bernardino
# 1             93581    58.0  26.0    NaN      NaN        San Bernardino
# 2             93581    58.0  26.0    NaN      NaN        San Bernardino
# 3             93581    44.0  17.0    NaN      NaN        San Bernardino
# 4             93581    44.0  17.0    NaN      NaN        San Bernardino
#
#    Measure Names Measure Values
# 0       Enrl GPA       3.855909
# 1        Adm GPA       3.663934
# 2        App GPA       3.534881
# 3       Enrl GPA       3.855909
# 4        Adm GPA       3.663934
#
# [5 rows x 22 columns]

# %%
merged_df_22 = pd.merge(ethn_22, california_income, on='City', how='inner')

merged_df_22 = pd.merge(merged_df_22, gen_22, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')

merged_df_22 = pd.merge(merged_df_22, gpa_22, on=['City','School'], how='inner')

merged_df_22.head()
# Out:
#                   Calculation1                  School     City  \
# 0  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 1  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 2  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 3  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 4  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
#
#   County/State/ Territory Count   All  African American  American Indian  \
# 0          San Bernardino   App  75.0               NaN              NaN
# 1          San Bernardino   App  75.0               NaN              NaN
# 2          San Bernardino   App  75.0               NaN              NaN
# 3          San Bernardino   Adm  55.0               NaN              NaN
# 4          San Bernardino   Adm  55.0               NaN              NaN
#
#    Hispanic/ Latinx  Pacific Islander  ...  Domestic Unknown  Int'l  \
# 0              67.0               NaN  ...               NaN    NaN
# 1              67.0               NaN  ...               NaN    NaN
# 2              67.0               NaN  ...               NaN    NaN
# 3              47.0               NaN  ...               NaN    NaN
# 4              47.0               NaN  ...               NaN    NaN
#
#    Household Income  Female  Male  Other  Unknown  County/State/Country  \
# 0             93581    49.0  21.0    NaN      NaN        San Bernardino
# 1             93581    49.0  21.0    NaN      NaN        San Bernardino
# 2             93581    49.0  21.0    NaN      NaN        San Bernardino
# 3             93581    38.0  12.0    NaN      NaN        San Bernardino
# 4             93581    38.0  12.0    NaN      NaN        San Bernardino
#
#    Measure Names Measure Values
# 0       Enrl GPA       3.971000
# 1        Adm GPA       3.831091
# 2        App GPA       3.659867
# 3       Enrl GPA       3.971000
# 4        Adm GPA       3.831091
#
# [5 rows x 22 columns]

# %%
merged_df_23 = pd.merge(ethn_23, california_income, on='City', how='inner')

merged_df_23 = pd.merge(merged_df_23, gen_23, on=['Calculation1', 'School', 'County/State/ Territory','Count','All', 'City'], how='inner')

merged_df_23 = pd.merge(merged_df_23, gpa_23, on=['City','School'], how='inner')

merged_df_23.head()
# Out:
#                   Calculation1                  School     City  \
# 0  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 1  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 2  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 3  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
# 4  A B MILLER HIGH SCHOOL50944  A B MILLER HIGH SCHOOL  Fontana
#
#   County/State/ Territory Count   All  African American  American Indian  \
# 0          San Bernardino   App  61.0               6.0              NaN
# 1          San Bernardino   App  61.0               6.0              NaN
# 2          San Bernardino   App  61.0               6.0              NaN
# 3          San Bernardino   Adm  54.0               6.0              NaN
# 4          San Bernardino   Adm  54.0               6.0              NaN
#
#    Hispanic/ Latinx  Pacific Islander  ...  Domestic Unknown  Int'l  \
# 0              51.0               NaN  ...               NaN    NaN
# 1              51.0               NaN  ...               NaN    NaN
# 2              51.0               NaN  ...               NaN    NaN
# 3              44.0               NaN  ...               NaN    NaN
# 4              44.0               NaN  ...               NaN    NaN
#
#    Household Income  Female  Male  Other  Unknown  County/State/Country  \
# 0             93581    51.0   8.0    NaN      NaN        San Bernardino
# 1             93581    51.0   8.0    NaN      NaN        San Bernardino
# 2             93581    51.0   8.0    NaN      NaN        San Bernardino
# 3             93581    45.0   7.0    NaN      NaN        San Bernardino
# 4             93581    45.0   7.0    NaN      NaN        San Bernardino
#
#    Measure Names Measure Values
# 0       Enrl GPA       3.887000
# 1        Adm GPA       3.808333
# 2        App GPA       3.741803
# 3       Enrl GPA       3.887000
# 4        Adm GPA       3.808333
#
# [5 rows x 22 columns]
